# %% [markdown]
# <a href="https://colab.research.google.com/github/Mostafa-babaee/classification/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install necessary packages
# !pip install rdkit scikit-learn torch torch-geometric
# Out:
# Collecting rdkit
#   Downloading rdkit-2024.3.6-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (4.0 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.5.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.0+cu121)
# Collecting torch-geometric
#   Downloading torch_geometric-2.6.1-py3-none-any.whl.metadata (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rdkit) (1.26.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit) (11.0.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from torch-geometric) (3.10.10)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.10/dist-packages (from torch-geometric) (5.9.5)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from torch-geometric) (3.2.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torch-geometric) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from torch-geometric) (4.66.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch-geometric) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch-geometric) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch-geometric) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch-geometric) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch-geometric) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch-geometric) (1.17.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch-geometric) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torch-geometric) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torch-geometric) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torch-geometric) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torch-geometric) (2024.8.30)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp->torch-geometric) (0.2.0)
# Downloading rdkit-2024.3.6-cp310-cp310-manylinux_2_28_x86_64.whl (32.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.8/32.8 MB 12.1 MB/s eta 0:00:00
# Downloading torch_geometric-2.6.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 14.9 MB/s eta 0:00:00
# Installing collected packages: rdkit, torch-geometric
# Successfully installed rdkit-2024.3.6 torch-geometric-2.6.1

# %%
# Import necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from rdkit import Chem
from rdkit.Chem import Descriptors, rdMolDescriptors
from sklearn.model_selection import KFold, cross_val_predict
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score
import numpy as np
from sklearn.ensemble import AdaBoostClassifier, ExtraTreesClassifier, GradientBoostingClassifier, RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import RidgeClassifier
from xgboost import XGBClassifier
from rdkit.Chem import AllChem

# %%
# Load our dataset
data = pd.read_csv('BBBP-processed2.csv')

# Generate molecular descriptors using the rdkit package
def calculate_descriptors(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol:
        mol_weight = Descriptors.MolWt(mol)
        num_atoms = mol.GetNumAtoms()
        num_bonds = mol.GetNumBonds()
        log_p = Descriptors.MolLogP(mol)
        TPSA = rdMolDescriptors.CalcTPSA(mol)
        return pd.Series([mol_weight, num_atoms, num_bonds, log_p, TPSA])
    else:
        return pd.Series([None, None, None, None, None])

# Add generated molecular descriptors to our dataframe
data[['Molecular Weight', 'Num Atoms', 'Num Bonds', 'LogP', 'TPSA']] = data['SMILES'].apply(calculate_descriptors)

# Correlation analysis
plt.figure(figsize=(6, 6))
numerical_data = data.select_dtypes(include=['number'])
sns.heatmap(numerical_data.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
# Out:
# [21:29:46] WARNING: not removing hydrogen atom without neighbors
# [21:29:46] WARNING: not removing hydrogen atom without neighbors
# [21:29:46] WARNING: not removing hydrogen atom without neighbors
# [21:29:46] WARNING: not removing hydrogen atom without neighbors
# [21:29:46] WARNING: not removing hydrogen atom without neighbors
# [21:29:46] WARNING: not removing hydrogen atom without neighbors
# [21:29:46] WARNING: not removing hydrogen atom without neighbors
# [21:29:47] WARNING: not removing hydrogen atom without neighbors
# [21:29:47] WARNING: not removing hydrogen atom without neighbors
# [21:29:47] WARNING: not removing hydrogen atom without neighbors
# [21:29:47] WARNING: not removing hydrogen atom without neighbors
# [21:29:47] WARNING: not removing hydrogen atom without neighbors
# [21:29:47] WARNING: not removing hydrogen atom without neighbors
# [21:29:47] WARNING: not removing hydrogen atom without neighbors
# [21:29:47] WARNING: not removing hydrogen atom without neighbors
# [21:29:48] WARNING: not removing hydrogen atom without neighbors
# [21:29:48] WARNING: not removing hydrogen atom without neighbors
# [21:29:48] WARNING: not removing hydrogen atom without neighbors
# [21:29:48] WARNING: not removing hydrogen atom without neighbors
# [21:29:48] WARNING: not removing hydrogen atom without neighbors
# [21:29:48] WARNING: not removing hydrogen atom without neighbors
# [21:29:48] WARNING: not removing hydrogen atom without neighbors
# [21:29:49] WARNING: not removing hydrogen atom without neighbors
# [21:29:49] WARNING: not removing hydrogen atom without neighbors
# [21:29:49] WARNING: not removing hydrogen atom without neighbors
# [21:29:49] WARNING: not removing hydrogen atom without neighbors
# [21:29:49] WARNING: not removing hydrogen atom without neighbors
# [21:29:49] WARNING: not removing hydrogen atom without neighbors
# [21:29:49] WARNING: not removing hydrogen atom without neighbors
# [21:29:49] WARNING: not removing hydrogen atom without neighbors
# [21:29:49] WARNING: not removing hydrogen atom without neighbors
# [21:29:49] WARNING: not removing hydrogen atom without neighbors
# [21:29:49] WARNING: not removing hydrogen atom without neighbors
# [21:29:50] WARNING: not removing hydrogen atom without neighbors
# [21:29:50] WARNING: not removing hydrogen atom without neighbors
# [21:29:50] WARNING: not removing hydrogen atom without neighbors
# [21:29:50] WARNING: not removing hydrogen atom without neighbors
# [21:29:50] WARNING: not removing hydrogen atom without neighbors
# [21:29:51] WARNING: not removing hydrogen atom without neighbors
# [21:29:51] WARNING: not removing hydrogen atom without neighbors

# %% [markdown]
# Training Classification Models Using the Most Common Models

# %%
# Morgan Fingerprints
morgan_gen = AllChem.GetMorganGenerator(radius=2, fpSize=2048)

def calculate_fingerprints(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol:
        fp = morgan_gen.GetFingerprint(mol)
        return np.array(fp)
    else:
        return np.zeros(2048)

# Generate molecular fingerprints
X = np.array([calculate_fingerprints(smiles) for smiles in data['SMILES']])
y = data['Active/Inactive']

# Function for model evaluation
def evaluate_model(model, model_name, X, y):
    kf = KFold(n_splits=5, shuffle=True, random_state=42)
    y_pred = cross_val_predict(model, X, y, cv=kf)

    acc = accuracy_score(y, y_pred)
    f1 = f1_score(y, y_pred)
    auc = roc_auc_score(y, y_pred)

    # Plotting
    sns.histplot(y_pred, color='b', alpha=0.6, label='Predicted')
    sns.histplot(y, color='r', alpha=0.4, label='True')
    plt.title(f'{model_name} \n Accuracy: {acc:.3f}, F1: {f1:.3f}, AUC: {auc:.3f}')
    plt.legend()
    plt.show()

    return acc, f1, auc
# Out:
# [21:29:58] WARNING: not removing hydrogen atom without neighbors
# [21:29:58] WARNING: not removing hydrogen atom without neighbors
# [21:29:58] WARNING: not removing hydrogen atom without neighbors
# [21:29:59] WARNING: not removing hydrogen atom without neighbors
# [21:29:59] WARNING: not removing hydrogen atom without neighbors
# [21:29:59] WARNING: not removing hydrogen atom without neighbors
# [21:29:59] WARNING: not removing hydrogen atom without neighbors
# [21:29:59] WARNING: not removing hydrogen atom without neighbors
# [21:29:59] WARNING: not removing hydrogen atom without neighbors
# [21:29:59] WARNING: not removing hydrogen atom without neighbors
# [21:29:59] WARNING: not removing hydrogen atom without neighbors
# [21:30:00] WARNING: not removing hydrogen atom without neighbors
# [21:30:00] WARNING: not removing hydrogen atom without neighbors
# [21:30:00] WARNING: not removing hydrogen atom without neighbors
# [21:30:00] WARNING: not removing hydrogen atom without neighbors
# [21:30:00] WARNING: not removing hydrogen atom without neighbors
# [21:30:00] WARNING: not removing hydrogen atom without neighbors
# [21:30:00] WARNING: not removing hydrogen atom without neighbors
# [21:30:00] WARNING: not removing hydrogen atom without neighbors
# [21:30:00] WARNING: not removing hydrogen atom without neighbors
# [21:30:00] WARNING: not removing hydrogen atom without neighbors
# [21:30:00] WARNING: not removing hydrogen atom without neighbors
# [21:30:01] WARNING: not removing hydrogen atom without neighbors
# [21:30:01] WARNING: not removing hydrogen atom without neighbors
# [21:30:01] WARNING: not removing hydrogen atom without neighbors
# [21:30:01] WARNING: not removing hydrogen atom without neighbors
# [21:30:01] WARNING: not removing hydrogen atom without neighbors
# [21:30:01] WARNING: not removing hydrogen atom without neighbors
# [21:30:01] WARNING: not removing hydrogen atom without neighbors
# [21:30:01] WARNING: not removing hydrogen atom without neighbors
# [21:30:01] WARNING: not removing hydrogen atom without neighbors
# [21:30:01] WARNING: not removing hydrogen atom without neighbors
# [21:30:01] WARNING: not removing hydrogen atom without neighbors
# [21:30:01] WARNING: not removing hydrogen atom without neighbors
# [21:30:01] WARNING: not removing hydrogen atom without neighbors
# [21:30:01] WARNING: not removing hydrogen atom without neighbors
# [21:30:01] WARNING: not removing hydrogen atom without neighbors
# [21:30:01] WARNING: not removing hydrogen atom without neighbors
# [21:30:02] WARNING: not removing hydrogen atom without neighbors
# [21:30:02] WARNING: not removing hydrogen atom without neighbors

# %% [markdown]
# Using RDKit Morgan Molecular Fingerprints as Descriptors

# %%
# AdaBoostClassifier (with SAMME algorithm)
ada_model = AdaBoostClassifier(algorithm='SAMME')
evaluate_model(ada_model, 'AdaBoost Classifier', X=X, y=y)

# DecisionTreeClassifier
dt_model = DecisionTreeClassifier()
evaluate_model(dt_model, 'Decision Tree Classifier', X=X, y=y)

# ExtraTreesClassifier
et_model = ExtraTreesClassifier()
evaluate_model(et_model, 'Extra Trees Classifier', X=X, y=y)

# GradientBoostingClassifier
gb_model = GradientBoostingClassifier()
evaluate_model(gb_model, 'Gradient Boosting Classifier', X=X, y=y)

# KNeighborsClassifier
knn_model = KNeighborsClassifier()
evaluate_model(knn_model, 'K-Neighbors Classifier', X=X, y=y)

# RandomForestClassifier
rf_model = RandomForestClassifier()
evaluate_model(rf_model, 'Random Forest Classifier', X=X, y=y)

# RidgeClassifier
ridge_model = RidgeClassifier()
evaluate_model(ridge_model, 'Ridge Classifier', X=X, y=y)

# XGBClassifier
xgb_model = XGBClassifier()
evaluate_model(xgb_model, 'XGB Classifier', X=X, y=y)
# Out:
# (0.8842569887199607, 0.9266169154228856, 0.8042864407686955)

# %% [markdown]
# Using RDKit Molecular Properties as Descriptors

# %%
# Select our molecular properties as features
X_properties = data[['Molecular Weight', 'Num Atoms', 'Num Bonds', 'LogP', 'TPSA']].values

# AdaBoostClassifier
ada_model = AdaBoostClassifier(algorithm='SAMME')
evaluate_model(ada_model, 'AdaBoost Classifier', X=X_properties, y=y)

# DecisionTreeClassifier
dt_model = DecisionTreeClassifier()
evaluate_model(dt_model, 'Decision Tree Classifier', X=X_properties, y=y)

# ExtraTreesClassifier
et_model = ExtraTreesClassifier()
evaluate_model(et_model, 'Extra Trees Classifier', X=X_properties, y=y)

# GradientBoostingClassifier
gb_model = GradientBoostingClassifier()
evaluate_model(gb_model, 'Gradient Boosting Classifier', X=X_properties, y=y)

# KNeighborsClassifier
knn_model = KNeighborsClassifier()
evaluate_model(knn_model, 'K-Neighbors Classifier', X=X_properties, y=y)

# RandomForestClassifier
rf_model = RandomForestClassifier()
evaluate_model(rf_model, 'Random Forest Classifier', X=X_properties, y=y)

# RidgeClassifier
ridge_model = RidgeClassifier()
evaluate_model(ridge_model, 'Ridge Classifier', X=X_properties, y=y)

# XGBClassifier
xgb_model = XGBClassifier()
evaluate_model(xgb_model, 'XGB Classifier', X=X_properties, y=y)
# Out:
# (0.8420794507111329, 0.8991859737006888, 0.7535758257052619)

# %% [markdown]
# Training A Graph Neural Network (GNN) Classification Model¶

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from rdkit import Chem
from rdkit.Chem import rdmolops
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader
import torch
from torch.nn import Sequential, Linear, ReLU, Sigmoid
from torch_geometric.nn import GCNConv, global_mean_pool
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix

# %%
# Load the dataset
data = pd.read_csv('BBBP-processed2.csv')

# Function to convert SMILES to PyTorch Geometric Data object (graph)
def mol_to_graph(smiles, target):
    mol = Chem.MolFromSmiles(smiles)
    if mol is None:
        return None

    # Convert atoms into node features
    atom_features = torch.tensor([atom.GetAtomicNum() for atom in mol.GetAtoms()], dtype=torch.float).view(-1, 1)

    # Create edge index (connectivity between atoms)
    adj_matrix = rdmolops.GetAdjacencyMatrix(mol)
    edge_index = np.array(np.nonzero(adj_matrix))  # Get non-zero indices in numpy array
    edge_index = torch.tensor(edge_index, dtype=torch.long)  # Directly convert to PyTorch tensor

    # Convert target into tensor
    target_tensor = torch.tensor([target], dtype=torch.float)

    # Create PyTorch Geometric data object
    graph_data = Data(x=atom_features, edge_index=edge_index, y=target_tensor)
    return graph_data

# Create a dataset of graphs and targets
graph_data_list = []
for smiles, activity in zip(data['SMILES'], data['Active/Inactive']):
    graph_data = mol_to_graph(smiles, activity)
    if graph_data is not None:
        graph_data_list.append(graph_data)

# Split the dataset into 5 folds for cross-validation
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# Define our GNN model for binary classification
class GNN(torch.nn.Module):
   def __init__(self, hidden_channels):
        super(GNN, self).__init__()
        self.conv1 = GCNConv(1, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, hidden_channels)
        self.fc = Sequential(Linear(hidden_channels, 64), ReLU(), Linear(64, 1), Sigmoid())

   def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index).relu()
        x = self.conv2(x, edge_index).relu()
        x = global_mean_pool(x, data.batch)
        x = self.fc(x)
        return x

# Functions for training and evaluation
def train(model, loader, optimizer, criterion):
    model.train()
    total_loss = 0
    for data in loader:
        optimizer.zero_grad()
        out = model(data)
        loss = criterion(out.view(-1), data.y.view(-1))
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    return total_loss / len(loader)

def evaluate(model, loader, criterion):
    model.eval()
    y_true = []
    y_pred = []
    total_loss = 0
    with torch.no_grad():
        for data in loader:
            out = model(data)
            y_true.extend(data.y.view(-1).tolist())
            y_pred.extend(out.view(-1).tolist())
            loss = criterion(out.view(-1), data.y.view(-1))
            total_loss += loss.item()

    y_pred_binary = [1 if pred > 0.5 else 0 for pred in y_pred]
    accuracy = accuracy_score(y_true, y_pred_binary)
    auc = roc_auc_score(y_true, y_pred)
    return total_loss / len(loader), accuracy, auc, y_true, y_pred_binary
# Out:
# [21:33:02] WARNING: not removing hydrogen atom without neighbors
# [21:33:02] WARNING: not removing hydrogen atom without neighbors
# [21:33:02] WARNING: not removing hydrogen atom without neighbors
# [21:33:02] WARNING: not removing hydrogen atom without neighbors
# [21:33:02] WARNING: not removing hydrogen atom without neighbors
# [21:33:02] WARNING: not removing hydrogen atom without neighbors
# [21:33:02] WARNING: not removing hydrogen atom without neighbors
# [21:33:02] WARNING: not removing hydrogen atom without neighbors
# [21:33:02] WARNING: not removing hydrogen atom without neighbors
# [21:33:02] WARNING: not removing hydrogen atom without neighbors
# [21:33:02] WARNING: not removing hydrogen atom without neighbors
# [21:33:02] WARNING: not removing hydrogen atom without neighbors
# [21:33:02] WARNING: not removing hydrogen atom without neighbors
# [21:33:02] WARNING: not removing hydrogen atom without neighbors
# [21:33:03] WARNING: not removing hydrogen atom without neighbors
# [21:33:03] WARNING: not removing hydrogen atom without neighbors
# [21:33:03] WARNING: not removing hydrogen atom without neighbors
# [21:33:03] WARNING: not removing hydrogen atom without neighbors
# [21:33:03] WARNING: not removing hydrogen atom without neighbors
# [21:33:03] WARNING: not removing hydrogen atom without neighbors
# [21:33:03] WARNING: not removing hydrogen atom without neighbors
# [21:33:03] WARNING: not removing hydrogen atom without neighbors
# [21:33:03] WARNING: not removing hydrogen atom without neighbors
# [21:33:03] WARNING: not removing hydrogen atom without neighbors
# [21:33:03] WARNING: not removing hydrogen atom without neighbors
# [21:33:03] WARNING: not removing hydrogen atom without neighbors
# [21:33:03] WARNING: not removing hydrogen atom without neighbors
# [21:33:03] WARNING: not removing hydrogen atom without neighbors
# [21:33:03] WARNING: not removing hydrogen atom without neighbors
# [21:33:03] WARNING: not removing hydrogen atom without neighbors
# [21:33:03] WARNING: not removing hydrogen atom without neighbors
# [21:33:03] WARNING: not removing hydrogen atom without neighbors
# [21:33:03] WARNING: not removing hydrogen atom without neighbors
# [21:33:03] WARNING: not removing hydrogen atom without neighbors
# [21:33:03] WARNING: not removing hydrogen atom without neighbors
# [21:33:03] WARNING: not removing hydrogen atom without neighbors
# [21:33:03] WARNING: not removing hydrogen atom without neighbors
# [21:33:03] WARNING: not removing hydrogen atom without neighbors
# [21:33:03] WARNING: not removing hydrogen atom without neighbors
# [21:33:03] WARNING: not removing hydrogen atom without neighbors

# %%
# Define hyperparameters here
hidden_channels = 128
learning_rate = 0.001
num_epochs = 1000
batch_size = 32

# Lists to store evaluation metrics
accuracy_scores = []
auc_scores = []

# K-Fold cross-validation
for fold, (train_idx, test_idx) in enumerate(kf.split(graph_data_list)):
    print(f"Fold {fold + 1}")

    # Create train and test loaders
    train_dataset = [graph_data_list[i] for i in train_idx]
    test_dataset = [graph_data_list[i] for i in test_idx]
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=batch_size)

    # Initialize the model, optimizer, and loss function
    model = GNN(hidden_channels=hidden_channels)
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    criterion = torch.nn.BCELoss()

    # Training loop
    train_losses = []
    test_losses = []

    for epoch in range(num_epochs):
        train_loss = train(model, train_loader, optimizer, criterion)
        test_loss, _, _, _, _ = evaluate(model, test_loader, criterion)

        train_losses.append(train_loss)
        test_losses.append(test_loss)

        if epoch % 10 == 0:
            print(f'Epoch {epoch}, Train Loss: {train_loss:.4f}, Test Loss: {test_loss:.4f}')

     # Evaluate the model
    _, accuracy, auc, y_true, y_pred_binary = evaluate(model, test_loader, criterion)
    accuracy_scores.append(accuracy)
    auc_scores.append(auc)

    # Plot confusion matrix
    conf_matrix = confusion_matrix(y_true, y_pred_binary)
    plt.figure(figsize=(4, 4))
    sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", cbar=False)
    plt.title(f'GNN Fold {fold + 1} - Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.show()

    # Plot loss vs epoch
    plt.figure(figsize=(4, 4))
    plt.plot(train_losses, label='Train Loss')
    plt.plot(test_losses, label='Test Loss')
    plt.title(f'GNN Fold {fold + 1} - Loss vs Epoch')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

# Print overall performance
print(f'Average Accuracy: {np.mean(accuracy_scores):.3f}, Average AUC: {np.mean(auc_scores):.3f}')
# Out:
# Fold 1
# Epoch 0, Train Loss: 0.5594, Test Loss: 0.5663
# Epoch 10, Train Loss: 0.5465, Test Loss: 0.5593
# Epoch 20, Train Loss: 0.5457, Test Loss: 0.5531
# Epoch 30, Train Loss: 0.5464, Test Loss: 0.5548
# Epoch 40, Train Loss: 0.5455, Test Loss: 0.5520
# Epoch 50, Train Loss: 0.5456, Test Loss: 0.5518
# Epoch 60, Train Loss: 0.5445, Test Loss: 0.5515
# Epoch 70, Train Loss: 0.5438, Test Loss: 0.5506
# Epoch 80, Train Loss: 0.5431, Test Loss: 0.5496
# Epoch 90, Train Loss: 0.5420, Test Loss: 0.5467
# Epoch 100, Train Loss: 0.5409, Test Loss: 0.5436
# Epoch 110, Train Loss: 0.5323, Test Loss: 0.5345
# Epoch 120, Train Loss: 0.5163, Test Loss: 0.5149
# Epoch 130, Train Loss: 0.5064, Test Loss: 0.5063
# Epoch 140, Train Loss: 0.4800, Test Loss: 0.4938
# Epoch 150, Train Loss: 0.4903, Test Loss: 0.4908
# Epoch 160, Train Loss: 0.4761, Test Loss: 0.4880
# Epoch 170, Train Loss: 0.4749, Test Loss: 0.4924
# Epoch 180, Train Loss: 0.4728, Test Loss: 0.4860
# Epoch 190, Train Loss: 0.4702, Test Loss: 0.4885
# Epoch 200, Train Loss: 0.4774, Test Loss: 0.4834
# Epoch 210, Train Loss: 0.4750, Test Loss: 0.4842
# Epoch 220, Train Loss: 0.4658, Test Loss: 0.4849
# Epoch 230, Train Loss: 0.4711, Test Loss: 0.4853
# Epoch 240, Train Loss: 0.4616, Test Loss: 0.4852
# Epoch 250, Train Loss: 0.4727, Test Loss: 0.4832
# Epoch 260, Train Loss: 0.4645, Test Loss: 0.4813
# Epoch 270, Train Loss: 0.4569, Test Loss: 0.4802
# Epoch 280, Train Loss: 0.4588, Test Loss: 0.4865
# Epoch 290, Train Loss: 0.4664, Test Loss: 0.5401
# Epoch 300, Train Loss: 0.4553, Test Loss: 0.4901
# Epoch 310, Train Loss: 0.4561, Test Loss: 0.4892
# Epoch 320, Train Loss: 0.4593, Test Loss: 0.4926
# Epoch 330, Train Loss: 0.4517, Test Loss: 0.4852
# Epoch 340, Train Loss: 0.4573, Test Loss: 0.4814
# Epoch 350, Train Loss: 0.4524, Test Loss: 0.4838
# Epoch 360, Train Loss: 0.4533, Test Loss: 0.4842
# Epoch 370, Train Loss: 0.4496, Test Loss: 0.5034
# Epoch 380, Train Loss: 0.4470, Test Loss: 0.4916
# Epoch 390, Train Loss: 0.4452, Test Loss: 0.4782
# Epoch 400, Train Loss: 0.4432, Test Loss: 0.4815
# Epoch 410, Train Loss: 0.4473, Test Loss: 0.4815
# Epoch 420, Train Loss: 0.4499, Test Loss: 0.5004
# Epoch 430, Train Loss: 0.4423, Test Loss: 0.5089
# Epoch 440, Train Loss: 0.4448, Test Loss: 0.4953
# Epoch 450, Train Loss: 0.4408, Test Loss: 0.4842
# Epoch 460, Train Loss: 0.4408, Test Loss: 0.4936
# Epoch 470, Train Loss: 0.4543, Test Loss: 0.4873
# Epoch 480, Train Loss: 0.4382, Test Loss: 0.4899
# Epoch 490, Train Loss: 0.4417, Test Loss: 0.4880
# Epoch 500, Train Loss: 0.4435, Test Loss: 0.4872
# Epoch 510, Train Loss: 0.4366, Test Loss: 0.4924
# Epoch 520, Train Loss: 0.4388, Test Loss: 0.4879
# Epoch 530, Train Loss: 0.4423, Test Loss: 0.4878
# Epoch 540, Train Loss: 0.4312, Test Loss: 0.7138
# Epoch 550, Train Loss: 0.4361, Test Loss: 0.4860
# Epoch 560, Train Loss: 0.4369, Test Loss: 0.6912
# Epoch 570, Train Loss: 0.4274, Test Loss: 0.6900
# Epoch 580, Train Loss: 0.4329, Test Loss: 0.6859
# Epoch 590, Train Loss: 0.4288, Test Loss: 0.6922
# Epoch 600, Train Loss: 0.4345, Test Loss: 0.6991
# Epoch 610, Train Loss: 0.4288, Test Loss: 0.6911
# Epoch 620, Train Loss: 0.4252, Test Loss: 0.6856
# Epoch 630, Train Loss: 0.4257, Test Loss: 0.6788
# Epoch 640, Train Loss: 0.4348, Test Loss: 0.7015
# Epoch 650, Train Loss: 0.4323, Test Loss: 0.6894
# Epoch 660, Train Loss: 0.4248, Test Loss: 0.6901
# Epoch 670, Train Loss: 0.4224, Test Loss: 0.6859
# Epoch 680, Train Loss: 0.4182, Test Loss: 0.6751
# Epoch 690, Train Loss: 0.4249, Test Loss: 0.6846
# Epoch 700, Train Loss: 0.4242, Test Loss: 0.6891
# Epoch 710, Train Loss: 0.4189, Test Loss: 0.6700
# Epoch 720, Train Loss: 0.4157, Test Loss: 0.6747
# Epoch 730, Train Loss: 0.4128, Test Loss: 0.6734
# Epoch 740, Train Loss: 0.4152, Test Loss: 0.6705
# Epoch 750, Train Loss: 0.4263, Test Loss: 0.6734
# Epoch 760, Train Loss: 0.4123, Test Loss: 0.6659
# Epoch 770, Train Loss: 0.4253, Test Loss: 0.6699
# Epoch 780, Train Loss: 0.4145, Test Loss: 0.6673
# Epoch 790, Train Loss: 0.4081, Test Loss: 0.6715
# Epoch 800, Train Loss: 0.4072, Test Loss: 0.6666
# Epoch 810, Train Loss: 0.4105, Test Loss: 0.6857
# Epoch 820, Train Loss: 0.4082, Test Loss: 0.6631
# Epoch 830, Train Loss: 0.4080, Test Loss: 0.6754
# Epoch 840, Train Loss: 0.4133, Test Loss: 0.6745
# Epoch 850, Train Loss: 0.4132, Test Loss: 0.6690
# Epoch 860, Train Loss: 0.4048, Test Loss: 0.6674
# Epoch 870, Train Loss: 0.4023, Test Loss: 0.6757
# Epoch 880, Train Loss: 0.4003, Test Loss: 0.6692
# Epoch 890, Train Loss: 0.3998, Test Loss: 0.6717
# Epoch 900, Train Loss: 0.4073, Test Loss: 0.6803
# Epoch 910, Train Loss: 0.3957, Test Loss: 0.6636
# Epoch 920, Train Loss: 0.3970, Test Loss: 0.6614
# Epoch 930, Train Loss: 0.4024, Test Loss: 0.6835
# Epoch 940, Train Loss: 0.3992, Test Loss: 0.7075
# Epoch 950, Train Loss: 0.4048, Test Loss: 0.6684
# Epoch 960, Train Loss: 0.4013, Test Loss: 0.6782
# Epoch 970, Train Loss: 0.3993, Test Loss: 0.6723
# Epoch 980, Train Loss: 0.3915, Test Loss: 0.6674
# Epoch 990, Train Loss: 0.3944, Test Loss: 0.6843
# Fold 2
# Epoch 0, Train Loss: 0.5677, Test Loss: 0.5397
# Epoch 10, Train Loss: 0.5516, Test Loss: 0.5318
# Epoch 20, Train Loss: 0.5523, Test Loss: 0.5323
# Epoch 30, Train Loss: 0.5512, Test Loss: 0.5290
# Epoch 40, Train Loss: 0.5513, Test Loss: 0.5446
# Epoch 50, Train Loss: 0.5510, Test Loss: 0.5282
# Epoch 60, Train Loss: 0.5518, Test Loss: 0.5330
# Epoch 70, Train Loss: 0.5499, Test Loss: 0.5284
# Epoch 80, Train Loss: 0.5487, Test Loss: 0.5248
# Epoch 90, Train Loss: 0.5464, Test Loss: 0.5229
# Epoch 100, Train Loss: 0.5387, Test Loss: 0.5091
# Epoch 110, Train Loss: 0.5163, Test Loss: 0.4946
# Epoch 120, Train Loss: 0.5003, Test Loss: 0.5291
# Epoch 130, Train Loss: 0.4897, Test Loss: 0.4610
# Epoch 140, Train Loss: 0.4844, Test Loss: 0.4873
# Epoch 150, Train Loss: 0.4822, Test Loss: 0.4687
# Epoch 160, Train Loss: 0.4779, Test Loss: 0.4653
# Epoch 170, Train Loss: 0.4722, Test Loss: 0.4639
# Epoch 180, Train Loss: 0.4795, Test Loss: 0.4637
# Epoch 190, Train Loss: 0.4671, Test Loss: 0.4599
# Epoch 200, Train Loss: 0.4751, Test Loss: 0.4525
# Epoch 210, Train Loss: 0.4675, Test Loss: 0.4566
# Epoch 220, Train Loss: 0.4693, Test Loss: 0.4554
# Epoch 230, Train Loss: 0.4666, Test Loss: 0.4778
# Epoch 240, Train Loss: 0.4697, Test Loss: 0.4590
# Epoch 250, Train Loss: 0.4648, Test Loss: 0.4674
# Epoch 260, Train Loss: 0.4642, Test Loss: 0.4500
# Epoch 270, Train Loss: 0.4695, Test Loss: 0.4534
# Epoch 280, Train Loss: 0.4631, Test Loss: 0.4475
# Epoch 290, Train Loss: 0.4661, Test Loss: 0.4556
# Epoch 300, Train Loss: 0.4634, Test Loss: 0.4569
# Epoch 310, Train Loss: 0.4693, Test Loss: 0.4457
# Epoch 320, Train Loss: 0.4621, Test Loss: 0.4522
# Epoch 330, Train Loss: 0.4598, Test Loss: 0.4578
# Epoch 340, Train Loss: 0.4610, Test Loss: 0.4458
# Epoch 350, Train Loss: 0.4599, Test Loss: 0.4465
# Epoch 360, Train Loss: 0.4596, Test Loss: 0.4481
# Epoch 370, Train Loss: 0.4611, Test Loss: 0.4459
# Epoch 380, Train Loss: 0.4583, Test Loss: 0.4418
# Epoch 390, Train Loss: 0.4620, Test Loss: 0.4511
# Epoch 400, Train Loss: 0.4570, Test Loss: 0.4419
# Epoch 410, Train Loss: 0.4590, Test Loss: 0.4478
# Epoch 420, Train Loss: 0.4543, Test Loss: 0.4779
# Epoch 430, Train Loss: 0.4554, Test Loss: 0.4407
# Epoch 440, Train Loss: 0.4555, Test Loss: 0.4455
# Epoch 450, Train Loss: 0.4520, Test Loss: 0.4405
# Epoch 460, Train Loss: 0.4580, Test Loss: 0.4680
# Epoch 470, Train Loss: 0.4493, Test Loss: 0.4406
# Epoch 480, Train Loss: 0.4488, Test Loss: 0.4531
# Epoch 490, Train Loss: 0.4482, Test Loss: 0.4396
# Epoch 500, Train Loss: 0.4480, Test Loss: 0.4451
# Epoch 510, Train Loss: 0.4621, Test Loss: 0.4606
# Epoch 520, Train Loss: 0.4494, Test Loss: 0.4358
# Epoch 530, Train Loss: 0.4442, Test Loss: 0.4330
# Epoch 540, Train Loss: 0.4470, Test Loss: 0.4309
# Epoch 550, Train Loss: 0.4444, Test Loss: 0.4320
# Epoch 560, Train Loss: 0.4486, Test Loss: 0.4446
# Epoch 570, Train Loss: 0.4600, Test Loss: 0.4308
# Epoch 580, Train Loss: 0.4396, Test Loss: 0.4314
# Epoch 590, Train Loss: 0.4436, Test Loss: 0.4300
# Epoch 600, Train Loss: 0.4397, Test Loss: 0.4500
# Epoch 610, Train Loss: 0.4493, Test Loss: 0.4536
# Epoch 620, Train Loss: 0.4397, Test Loss: 0.4395
# Epoch 630, Train Loss: 0.4389, Test Loss: 0.4297
# Epoch 640, Train Loss: 0.4374, Test Loss: 0.4304
# Epoch 650, Train Loss: 0.4401, Test Loss: 0.4286
# Epoch 660, Train Loss: 0.4455, Test Loss: 0.4286
# Epoch 670, Train Loss: 0.4357, Test Loss: 0.4280
# Epoch 680, Train Loss: 0.4452, Test Loss: 0.4332
# Epoch 690, Train Loss: 0.4367, Test Loss: 0.4418
# Epoch 700, Train Loss: 0.4358, Test Loss: 0.4269
# Epoch 710, Train Loss: 0.4354, Test Loss: 0.4308
# Epoch 720, Train Loss: 0.4392, Test Loss: 0.4534
# Epoch 730, Train Loss: 0.4454, Test Loss: 0.4477
# Epoch 740, Train Loss: 0.4368, Test Loss: 0.4296
# Epoch 750, Train Loss: 0.4355, Test Loss: 0.4275
# Epoch 760, Train Loss: 0.4345, Test Loss: 0.4240
# Epoch 770, Train Loss: 0.4330, Test Loss: 0.4285
# Epoch 780, Train Loss: 0.4306, Test Loss: 0.4291
# Epoch 790, Train Loss: 0.4291, Test Loss: 0.4593
# Epoch 800, Train Loss: 0.4357, Test Loss: 0.4338
# Epoch 810, Train Loss: 0.4416, Test Loss: 0.4504
# Epoch 820, Train Loss: 0.4284, Test Loss: 0.4620
# Epoch 830, Train Loss: 0.4348, Test Loss: 0.4333
# Epoch 840, Train Loss: 0.4359, Test Loss: 0.4288
# Epoch 850, Train Loss: 0.4279, Test Loss: 0.4194
# Epoch 860, Train Loss: 0.4301, Test Loss: 0.4324
# Epoch 870, Train Loss: 0.4247, Test Loss: 0.4224
# Epoch 880, Train Loss: 0.4247, Test Loss: 0.4304
# Epoch 890, Train Loss: 0.4355, Test Loss: 0.4508
# Epoch 900, Train Loss: 0.4232, Test Loss: 0.4246
# Epoch 910, Train Loss: 0.4239, Test Loss: 0.4289
# Epoch 920, Train Loss: 0.4223, Test Loss: 0.4488
# Epoch 930, Train Loss: 0.4211, Test Loss: 0.4203
# Epoch 940, Train Loss: 0.4314, Test Loss: 0.4431
# Epoch 950, Train Loss: 0.4236, Test Loss: 0.4170
# Epoch 960, Train Loss: 0.4232, Test Loss: 0.4201
# Epoch 970, Train Loss: 0.4226, Test Loss: 0.4253
# Epoch 980, Train Loss: 0.4191, Test Loss: 0.4186
# Epoch 990, Train Loss: 0.4289, Test Loss: 0.4239
# Fold 3
# Epoch 0, Train Loss: 0.5619, Test Loss: 0.5576
# Epoch 10, Train Loss: 0.5468, Test Loss: 0.5588
# Epoch 20, Train Loss: 0.5498, Test Loss: 0.5574
# Epoch 30, Train Loss: 0.5461, Test Loss: 0.5605
# Epoch 40, Train Loss: 0.5436, Test Loss: 0.5567
# Epoch 50, Train Loss: 0.5425, Test Loss: 0.5566
# Epoch 60, Train Loss: 0.5399, Test Loss: 0.5563
# Epoch 70, Train Loss: 0.5350, Test Loss: 0.5654
# Epoch 80, Train Loss: 0.5113, Test Loss: 0.5773
# Epoch 90, Train Loss: 0.4985, Test Loss: 0.5273
# Epoch 100, Train Loss: 0.4885, Test Loss: 0.5075
# Epoch 110, Train Loss: 0.4776, Test Loss: 0.5240
# Epoch 120, Train Loss: 0.4813, Test Loss: 0.5531
# Epoch 130, Train Loss: 0.4772, Test Loss: 0.5105
# Epoch 140, Train Loss: 0.4704, Test Loss: 0.5177
# Epoch 150, Train Loss: 0.4728, Test Loss: 0.4991
# Epoch 160, Train Loss: 0.4734, Test Loss: 0.5152
# Epoch 170, Train Loss: 0.4669, Test Loss: 0.5422
# Epoch 180, Train Loss: 0.4763, Test Loss: 0.4956
# Epoch 190, Train Loss: 0.4670, Test Loss: 0.5096
# Epoch 200, Train Loss: 0.4631, Test Loss: 0.4951
# Epoch 210, Train Loss: 0.4615, Test Loss: 0.5099
# Epoch 220, Train Loss: 0.4663, Test Loss: 0.4938
# Epoch 230, Train Loss: 0.4669, Test Loss: 0.4887
# Epoch 240, Train Loss: 0.4607, Test Loss: 0.4906
# Epoch 250, Train Loss: 0.4534, Test Loss: 0.4861
# Epoch 260, Train Loss: 0.4547, Test Loss: 0.4871
# Epoch 270, Train Loss: 0.4496, Test Loss: 0.4828
# Epoch 280, Train Loss: 0.4610, Test Loss: 0.4803
# Epoch 290, Train Loss: 0.4464, Test Loss: 0.4765
# Epoch 300, Train Loss: 0.4441, Test Loss: 0.4802
# Epoch 310, Train Loss: 0.4418, Test Loss: 0.4986
# Epoch 320, Train Loss: 0.4426, Test Loss: 0.4791
# Epoch 330, Train Loss: 0.4443, Test Loss: 0.5198
# Epoch 340, Train Loss: 0.4388, Test Loss: 0.4850
# Epoch 350, Train Loss: 0.4447, Test Loss: 0.4723
# Epoch 360, Train Loss: 0.4430, Test Loss: 0.4782
# Epoch 370, Train Loss: 0.4381, Test Loss: 0.4763
# Epoch 380, Train Loss: 0.4364, Test Loss: 0.4692
# Epoch 390, Train Loss: 0.4394, Test Loss: 0.4811
# Epoch 400, Train Loss: 0.4366, Test Loss: 0.4803
# Epoch 410, Train Loss: 0.4383, Test Loss: 0.4784
# Epoch 420, Train Loss: 0.4318, Test Loss: 0.4998
# Epoch 430, Train Loss: 0.4321, Test Loss: 0.4778
# Epoch 440, Train Loss: 0.4294, Test Loss: 0.4734
# Epoch 450, Train Loss: 0.4335, Test Loss: 0.4805
# Epoch 460, Train Loss: 0.4381, Test Loss: 0.4665
# Epoch 470, Train Loss: 0.4259, Test Loss: 0.5028
# Epoch 480, Train Loss: 0.4285, Test Loss: 0.5068
# Epoch 490, Train Loss: 0.4282, Test Loss: 0.4689
# Epoch 500, Train Loss: 0.4370, Test Loss: 0.4891
# Epoch 510, Train Loss: 0.4277, Test Loss: 0.5440
# Epoch 520, Train Loss: 0.4285, Test Loss: 0.5085
# Epoch 530, Train Loss: 0.4221, Test Loss: 0.4684
# Epoch 540, Train Loss: 0.4208, Test Loss: 0.4668
# Epoch 550, Train Loss: 0.4235, Test Loss: 0.4919
# Epoch 560, Train Loss: 0.4256, Test Loss: 0.4891
# Epoch 570, Train Loss: 0.4139, Test Loss: 0.4876
# Epoch 580, Train Loss: 0.4193, Test Loss: 0.4773
# Epoch 590, Train Loss: 0.4199, Test Loss: 0.5263
# Epoch 600, Train Loss: 0.4190, Test Loss: 0.4959
# Epoch 610, Train Loss: 0.4261, Test Loss: 0.4656
# Epoch 620, Train Loss: 0.4108, Test Loss: 0.4853
# Epoch 630, Train Loss: 0.4172, Test Loss: 0.4677
# Epoch 640, Train Loss: 0.4055, Test Loss: 0.4852
# Epoch 650, Train Loss: 0.4184, Test Loss: 0.4800
# Epoch 660, Train Loss: 0.4101, Test Loss: 0.4648
# Epoch 670, Train Loss: 0.4098, Test Loss: 0.5058
# Epoch 680, Train Loss: 0.4082, Test Loss: 0.4587
# Epoch 690, Train Loss: 0.4182, Test Loss: 0.4967
# Epoch 700, Train Loss: 0.4113, Test Loss: 0.4693
# Epoch 710, Train Loss: 0.4318, Test Loss: 0.4757
# Epoch 720, Train Loss: 0.4116, Test Loss: 0.5021
# Epoch 730, Train Loss: 0.4203, Test Loss: 0.4907
# Epoch 740, Train Loss: 0.4044, Test Loss: 0.4628
# Epoch 750, Train Loss: 0.4207, Test Loss: 0.5073
# Epoch 760, Train Loss: 0.4060, Test Loss: 0.4695
# Epoch 770, Train Loss: 0.4081, Test Loss: 0.4766
# Epoch 780, Train Loss: 0.4037, Test Loss: 0.4675
# Epoch 790, Train Loss: 0.4113, Test Loss: 0.4705
# Epoch 800, Train Loss: 0.4026, Test Loss: 0.4737
# Epoch 810, Train Loss: 0.4164, Test Loss: 0.4558
# Epoch 820, Train Loss: 0.4164, Test Loss: 0.5018
# Epoch 830, Train Loss: 0.4020, Test Loss: 0.4736
# Epoch 840, Train Loss: 0.4043, Test Loss: 0.4792
# Epoch 850, Train Loss: 0.4048, Test Loss: 0.4754
# Epoch 860, Train Loss: 0.3948, Test Loss: 0.4558
# Epoch 870, Train Loss: 0.4041, Test Loss: 0.4969
# Epoch 880, Train Loss: 0.4003, Test Loss: 0.4575
# Epoch 890, Train Loss: 0.3982, Test Loss: 0.4685
# Epoch 900, Train Loss: 0.4070, Test Loss: 0.4818
# Epoch 910, Train Loss: 0.4114, Test Loss: 0.4652
# Epoch 920, Train Loss: 0.3969, Test Loss: 0.4752
# Epoch 930, Train Loss: 0.3948, Test Loss: 0.4564
# Epoch 940, Train Loss: 0.3993, Test Loss: 0.4963
# Epoch 950, Train Loss: 0.3889, Test Loss: 0.4488
# Epoch 960, Train Loss: 0.3896, Test Loss: 0.4656
# Epoch 970, Train Loss: 0.3956, Test Loss: 0.4670
# Epoch 980, Train Loss: 0.3953, Test Loss: 0.4535
# Epoch 990, Train Loss: 0.3905, Test Loss: 0.4600
# Fold 4
# Epoch 0, Train Loss: 0.5668, Test Loss: 0.5620
# Epoch 10, Train Loss: 0.5481, Test Loss: 0.5620
# Epoch 20, Train Loss: 0.5453, Test Loss: 0.5641
# Epoch 30, Train Loss: 0.5468, Test Loss: 0.5613
# Epoch 40, Train Loss: 0.5441, Test Loss: 0.5609
# Epoch 50, Train Loss: 0.5456, Test Loss: 0.5669
# Epoch 60, Train Loss: 0.5420, Test Loss: 0.5601
# Epoch 70, Train Loss: 0.5400, Test Loss: 0.5587
# Epoch 80, Train Loss: 0.5366, Test Loss: 0.5574
# Epoch 90, Train Loss: 0.5275, Test Loss: 0.5506
# Epoch 100, Train Loss: 0.5108, Test Loss: 0.5185
# Epoch 110, Train Loss: 0.5015, Test Loss: 0.5151
# Epoch 120, Train Loss: 0.4879, Test Loss: 0.4937
# Epoch 130, Train Loss: 0.4841, Test Loss: 0.4911
# Epoch 140, Train Loss: 0.4795, Test Loss: 0.4881
# Epoch 150, Train Loss: 0.4789, Test Loss: 0.4856
# Epoch 160, Train Loss: 0.4770, Test Loss: 0.4887
# Epoch 170, Train Loss: 0.4757, Test Loss: 0.4818
# Epoch 180, Train Loss: 0.4712, Test Loss: 0.4851
# Epoch 190, Train Loss: 0.4748, Test Loss: 0.4857
# Epoch 200, Train Loss: 0.4694, Test Loss: 0.4788
# Epoch 210, Train Loss: 0.4717, Test Loss: 0.4778
# Epoch 220, Train Loss: 0.4645, Test Loss: 0.4891
# Epoch 230, Train Loss: 0.4624, Test Loss: 0.4851
# Epoch 240, Train Loss: 0.4669, Test Loss: 0.4778
# Epoch 250, Train Loss: 0.4790, Test Loss: 0.4817
# Epoch 260, Train Loss: 0.4656, Test Loss: 0.4705
# Epoch 270, Train Loss: 0.4614, Test Loss: 0.4698
# Epoch 280, Train Loss: 0.4615, Test Loss: 0.4679
# Epoch 290, Train Loss: 0.4625, Test Loss: 0.4940
# Epoch 300, Train Loss: 0.4563, Test Loss: 0.4716
# Epoch 310, Train Loss: 0.4548, Test Loss: 0.4695
# Epoch 320, Train Loss: 0.4531, Test Loss: 0.4721
# Epoch 330, Train Loss: 0.4496, Test Loss: 0.4703
# Epoch 340, Train Loss: 0.4501, Test Loss: 0.4676
# Epoch 350, Train Loss: 0.4592, Test Loss: 0.4698
# Epoch 360, Train Loss: 0.4561, Test Loss: 0.4688
# Epoch 370, Train Loss: 0.4474, Test Loss: 0.4773
# Epoch 380, Train Loss: 0.4536, Test Loss: 0.5225
# Epoch 390, Train Loss: 0.4508, Test Loss: 0.4873
# Epoch 400, Train Loss: 0.4510, Test Loss: 0.4685
# Epoch 410, Train Loss: 0.4413, Test Loss: 0.4670
# Epoch 420, Train Loss: 0.4532, Test Loss: 0.4745
# Epoch 430, Train Loss: 0.4440, Test Loss: 0.4715
# Epoch 440, Train Loss: 0.4421, Test Loss: 0.5043
# Epoch 450, Train Loss: 0.4389, Test Loss: 0.4781
# Epoch 460, Train Loss: 0.4414, Test Loss: 0.4806
# Epoch 470, Train Loss: 0.4439, Test Loss: 0.4780
# Epoch 480, Train Loss: 0.4315, Test Loss: 0.4724
# Epoch 490, Train Loss: 0.4408, Test Loss: 0.4651
# Epoch 500, Train Loss: 0.4345, Test Loss: 0.5014
# Epoch 510, Train Loss: 0.4393, Test Loss: 0.4661
# Epoch 520, Train Loss: 0.4332, Test Loss: 0.4743
# Epoch 530, Train Loss: 0.4314, Test Loss: 0.4805
# Epoch 540, Train Loss: 0.4288, Test Loss: 0.4647
# Epoch 550, Train Loss: 0.4271, Test Loss: 0.4642
# Epoch 560, Train Loss: 0.4312, Test Loss: 0.4600
# Epoch 570, Train Loss: 0.4417, Test Loss: 0.4783
# Epoch 580, Train Loss: 0.4283, Test Loss: 0.4614
# Epoch 590, Train Loss: 0.4355, Test Loss: 0.4906
# Epoch 600, Train Loss: 0.4266, Test Loss: 0.4633
# Epoch 610, Train Loss: 0.4272, Test Loss: 0.4599
# Epoch 620, Train Loss: 0.4212, Test Loss: 0.4658
# Epoch 630, Train Loss: 0.4229, Test Loss: 0.4620
# Epoch 640, Train Loss: 0.4216, Test Loss: 0.4740
# Epoch 650, Train Loss: 0.4334, Test Loss: 0.4689
# Epoch 660, Train Loss: 0.4245, Test Loss: 0.4623
# Epoch 670, Train Loss: 0.4149, Test Loss: 0.4623
# Epoch 680, Train Loss: 0.4220, Test Loss: 0.4986
# Epoch 690, Train Loss: 0.4183, Test Loss: 0.4536
# Epoch 700, Train Loss: 0.4466, Test Loss: 0.4748
# Epoch 710, Train Loss: 0.4179, Test Loss: 0.4579
# Epoch 720, Train Loss: 0.4252, Test Loss: 0.4933
# Epoch 730, Train Loss: 0.4211, Test Loss: 0.4577
# Epoch 740, Train Loss: 0.4151, Test Loss: 0.4633
# Epoch 750, Train Loss: 0.4192, Test Loss: 0.4820
# Epoch 760, Train Loss: 0.4204, Test Loss: 0.4518
# Epoch 770, Train Loss: 0.4168, Test Loss: 0.4497
# Epoch 780, Train Loss: 0.4082, Test Loss: 0.4619
# Epoch 790, Train Loss: 0.4186, Test Loss: 0.4565
# Epoch 800, Train Loss: 0.4173, Test Loss: 0.4506
# Epoch 810, Train Loss: 0.4309, Test Loss: 0.4518
# Epoch 820, Train Loss: 0.4113, Test Loss: 0.4494
# Epoch 830, Train Loss: 0.4109, Test Loss: 0.4464
# Epoch 840, Train Loss: 0.4106, Test Loss: 0.4637
# Epoch 850, Train Loss: 0.4226, Test Loss: 0.4637
# Epoch 860, Train Loss: 0.4117, Test Loss: 0.4439
# Epoch 870, Train Loss: 0.4116, Test Loss: 0.4410
# Epoch 880, Train Loss: 0.4193, Test Loss: 0.4513
# Epoch 890, Train Loss: 0.4061, Test Loss: 0.4490
# Epoch 900, Train Loss: 0.4092, Test Loss: 0.4623
# Epoch 910, Train Loss: 0.4122, Test Loss: 0.4425
# Epoch 920, Train Loss: 0.4071, Test Loss: 0.4620
# Epoch 930, Train Loss: 0.4168, Test Loss: 0.4432
# Epoch 940, Train Loss: 0.4078, Test Loss: 0.4678
# Epoch 950, Train Loss: 0.4048, Test Loss: 0.4600
# Epoch 960, Train Loss: 0.4096, Test Loss: 0.4437
# Epoch 970, Train Loss: 0.4071, Test Loss: 0.4537
# Epoch 980, Train Loss: 0.4298, Test Loss: 0.4537
# Epoch 990, Train Loss: 0.4083, Test Loss: 0.4476
# Fold 5
# Epoch 0, Train Loss: 0.5830, Test Loss: 0.5212
# Epoch 10, Train Loss: 0.5578, Test Loss: 0.5170
# Epoch 20, Train Loss: 0.5583, Test Loss: 0.5139
# Epoch 30, Train Loss: 0.5576, Test Loss: 0.5115
# Epoch 40, Train Loss: 0.5570, Test Loss: 0.5154
# Epoch 50, Train Loss: 0.5573, Test Loss: 0.5086
# Epoch 60, Train Loss: 0.5559, Test Loss: 0.5123
# Epoch 70, Train Loss: 0.5559, Test Loss: 0.5135
# Epoch 80, Train Loss: 0.5542, Test Loss: 0.5139
# Epoch 90, Train Loss: 0.5553, Test Loss: 0.5070
# Epoch 100, Train Loss: 0.5533, Test Loss: 0.5031
# Epoch 110, Train Loss: 0.5561, Test Loss: 0.5021
# Epoch 120, Train Loss: 0.5329, Test Loss: 0.4783
# Epoch 130, Train Loss: 0.5113, Test Loss: 0.4574
# Epoch 140, Train Loss: 0.5086, Test Loss: 0.4457
# Epoch 150, Train Loss: 0.4942, Test Loss: 0.4447
# Epoch 160, Train Loss: 0.4892, Test Loss: 0.4554
# Epoch 170, Train Loss: 0.4873, Test Loss: 0.4501
# Epoch 180, Train Loss: 0.4857, Test Loss: 0.4407
# Epoch 190, Train Loss: 0.4911, Test Loss: 0.4285
# Epoch 200, Train Loss: 0.4838, Test Loss: 0.4369
# Epoch 210, Train Loss: 0.4868, Test Loss: 0.4447
# Epoch 220, Train Loss: 0.4862, Test Loss: 0.4406
# Epoch 230, Train Loss: 0.4804, Test Loss: 0.4215
# Epoch 240, Train Loss: 0.4887, Test Loss: 0.4253
# Epoch 250, Train Loss: 0.4814, Test Loss: 0.4214
# Epoch 260, Train Loss: 0.4852, Test Loss: 0.4243
# Epoch 270, Train Loss: 0.4751, Test Loss: 0.4354
# Epoch 280, Train Loss: 0.4851, Test Loss: 0.4338
# Epoch 290, Train Loss: 0.4762, Test Loss: 0.4237
# Epoch 300, Train Loss: 0.4870, Test Loss: 0.4411
# Epoch 310, Train Loss: 0.4777, Test Loss: 0.4601
# Epoch 320, Train Loss: 0.4786, Test Loss: 0.4215
# Epoch 330, Train Loss: 0.4747, Test Loss: 0.4244
# Epoch 340, Train Loss: 0.4786, Test Loss: 0.4205
# Epoch 350, Train Loss: 0.4743, Test Loss: 0.4359
# Epoch 360, Train Loss: 0.4751, Test Loss: 0.4367
# Epoch 370, Train Loss: 0.4801, Test Loss: 0.4448
# Epoch 380, Train Loss: 0.4723, Test Loss: 0.4247
# Epoch 390, Train Loss: 0.4731, Test Loss: 0.4207
# Epoch 400, Train Loss: 0.4712, Test Loss: 0.4234
# Epoch 410, Train Loss: 0.4716, Test Loss: 0.4244
# Epoch 420, Train Loss: 0.4770, Test Loss: 0.4253
# Epoch 430, Train Loss: 0.4705, Test Loss: 0.4396
# Epoch 440, Train Loss: 0.4681, Test Loss: 0.4315
# Epoch 450, Train Loss: 0.4678, Test Loss: 0.4314
# Epoch 460, Train Loss: 0.4669, Test Loss: 0.4263
# Epoch 470, Train Loss: 0.4657, Test Loss: 0.4285
# Epoch 480, Train Loss: 0.4632, Test Loss: 0.4342
# Epoch 490, Train Loss: 0.4643, Test Loss: 0.4365
# Epoch 500, Train Loss: 0.4645, Test Loss: 0.4414
# Epoch 510, Train Loss: 0.4665, Test Loss: 0.4333
# Epoch 520, Train Loss: 0.4673, Test Loss: 0.4384
# Epoch 530, Train Loss: 0.4625, Test Loss: 0.6593
# Epoch 540, Train Loss: 0.4632, Test Loss: 0.4423
# Epoch 550, Train Loss: 0.4594, Test Loss: 0.6616
# Epoch 560, Train Loss: 0.4634, Test Loss: 0.6515
# Epoch 570, Train Loss: 0.4612, Test Loss: 0.6435
# Epoch 580, Train Loss: 0.4610, Test Loss: 0.6459
# Epoch 590, Train Loss: 0.4690, Test Loss: 0.6420
# Epoch 600, Train Loss: 0.4731, Test Loss: 0.6829
# Epoch 610, Train Loss: 0.4536, Test Loss: 0.6396
# Epoch 620, Train Loss: 0.4556, Test Loss: 0.6382
# Epoch 630, Train Loss: 0.4714, Test Loss: 0.6606
# Epoch 640, Train Loss: 0.4664, Test Loss: 0.6849
# Epoch 650, Train Loss: 0.4504, Test Loss: 0.6434
# Epoch 660, Train Loss: 0.4543, Test Loss: 0.6511
# Epoch 670, Train Loss: 0.4556, Test Loss: 0.6623
# Epoch 680, Train Loss: 0.4591, Test Loss: 0.6483
# Epoch 690, Train Loss: 0.4554, Test Loss: 0.6439
# Epoch 700, Train Loss: 0.4533, Test Loss: 0.6375
# Epoch 710, Train Loss: 0.4575, Test Loss: 0.6458
# Epoch 720, Train Loss: 0.4538, Test Loss: 0.6394
# Epoch 730, Train Loss: 0.4483, Test Loss: 0.6607
# Epoch 740, Train Loss: 0.4477, Test Loss: 0.6390
# Epoch 750, Train Loss: 0.4470, Test Loss: 0.6462
# Epoch 760, Train Loss: 0.4511, Test Loss: 0.6392
# Epoch 770, Train Loss: 0.4526, Test Loss: 0.6473
# Epoch 780, Train Loss: 0.4525, Test Loss: 0.6533
# Epoch 790, Train Loss: 0.4505, Test Loss: 0.6815
# Epoch 800, Train Loss: 0.4506, Test Loss: 0.6404
# Epoch 810, Train Loss: 0.4437, Test Loss: 0.6469
# Epoch 820, Train Loss: 0.4459, Test Loss: 0.6404
# Epoch 830, Train Loss: 0.4415, Test Loss: 0.6412
# Epoch 840, Train Loss: 0.4480, Test Loss: 0.6638
# Epoch 850, Train Loss: 0.4418, Test Loss: 0.6324
# Epoch 860, Train Loss: 0.4485, Test Loss: 0.6456
# Epoch 870, Train Loss: 0.4397, Test Loss: 0.6414
# Epoch 880, Train Loss: 0.4428, Test Loss: 0.6575
# Epoch 890, Train Loss: 0.4402, Test Loss: 0.6468
# Epoch 900, Train Loss: 0.4407, Test Loss: 0.6352
# Epoch 910, Train Loss: 0.4418, Test Loss: 0.6411
# Epoch 920, Train Loss: 0.4476, Test Loss: 0.6422
# Epoch 930, Train Loss: 0.4421, Test Loss: 0.6348
# Epoch 940, Train Loss: 0.4387, Test Loss: 0.6297
# Epoch 950, Train Loss: 0.4407, Test Loss: 0.6395
# Epoch 960, Train Loss: 0.4419, Test Loss: 0.6386
# Epoch 970, Train Loss: 0.4405, Test Loss: 0.6572
# Epoch 980, Train Loss: 0.4399, Test Loss: 0.6355
# Epoch 990, Train Loss: 0.4407, Test Loss: 0.6419
# Average Accuracy: 0.815, Average AUC: 0.782
